# %% [markdown]
# # Project 1
# Hello World using LangChain

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.7/412.7 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.32
#     Uninstalling langchain-core-0.3.32:
#       Successfully uninstalled langchain-core-0.3.32
# ...

# %%
# !pip install langchain_community

# %%
from langchain.chat_models import ChatOpenAI

# %%
import os
os.environ['AIzaSyABVnK8LhP8Cff_TZzjX6bXgKD1t58a_Vc'] = 'AIzaSyABVnK8LhP8Cff_TZzjX6bXgKD1t58a_Vc'

# %%
from langchain_openai import ChatOpenAI

# Initialize the ChatOpenAI model with your OpenAI API key
chat_model = ChatOpenAI(openai_api_key="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")

# Print the response=
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------
